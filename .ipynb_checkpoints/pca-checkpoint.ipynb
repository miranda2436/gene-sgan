# 1799  0.952708  0.979352  0.747240  0.684579  0.686912  0.877264  0.920842
#
#         roi144
# 0     0.918699
# 1     1.016048
# 2     0.896502
# 3     0.860507
# 4     1.075277
# ...        ...
# 1795  1.018546
# 1796  1.054795
# 1797  1.084125
# 1798  0.943671
# 1799  1.112127
#
# [1800 rows x 147 columns]

# %%
fig, ax = plt.subplots()
# PCA
pca = PCA(n_components=2,random_state=42)

pca_result = pca.fit_transform(imaging_minimal)
print(pca.explained_variance_ratio_)
print(pca_result)


for l, c, m in zip([-1,1], ["lightgreen", "black"], ('^', 's')):
    ax.scatter(pca_result[y == l, 0],
                pca_result[y == l, 1],
                color=c,
                label='cluster %s' % l,
                alpha=0.9,
                marker=m
                )

plt.title("PCA analysis of Gene-SGAN imaging toy dataset")
labels = ["Healthy","Patient"]
fig.legend(labels, loc='lower center',ncol=len(labels))
# Out:
# [0.09564559 0.06882265]
# [[-0.60566513  0.07269842]
#  [-0.53009271 -0.1105349 ]
#  [-0.55115973 -0.17241884]
#  ...
#  [ 0.16343098  0.02571888]
#  [ 0.92047948  0.13546029]
#  [ 0.48383664  0.15166097]]

# %%
# filtering out patient only data 

patient_data = imaging_data.loc[imaging_data["diagnosis"] == 1,:]
patient_minimal = patient_data.iloc[:,2:]
print(patient_minimal)
ground_truth = pd.read_csv("toy_data_ground_truth.csv")
y = ground_truth.iloc[:,1]
print(y)
# Out:
#           roi0      roi1      roi2      roi3      roi4      roi5      roi6  \
# 600   1.064109  0.953707  1.034319  1.020244  0.702135  0.882553  1.133318
# 601   1.045436  0.933038  1.056347  1.024579  0.777969  0.857977  0.901510
# 602   1.046640  1.077168  1.047961  0.865588  0.913810  0.771641  0.719595
# 603   0.746936  1.070795  1.024257  1.166989  0.873117  1.026943  1.014518
# 604   1.104929  1.004432  1.097849  1.077099  0.859668  0.695727  1.112147
# ...        ...       ...       ...       ...       ...       ...       ...
# 1795  0.995731  0.902431  1.062839  0.888057  0.966019  0.984647  1.043323
# 1796  1.110225  1.005496  0.918571  1.050134  0.715727  0.779421  1.090959
# 1797  0.980747  1.100119  1.013491  0.867414  0.786782  0.945555  1.045850
# 1798  0.913652  0.943914  0.826538  1.054494  0.868547  0.766069  0.856117
# 1799  0.991884  1.077665  1.048818  0.872075  0.860728  0.877536  1.010036
#
#           roi7      roi8      roi9  ...    roi135    roi136    roi137  \
# 600   1.001985  0.917441  0.993280  ...  0.818725  1.009122  1.046413
# 601   0.924565  1.060921  0.839870  ...  1.082356  0.937559  0.994714
# 602   1.053444  1.131132  1.064238  ...  0.946108  0.975011  0.960651
# 603   0.896677  1.008153  1.120909  ...  0.979449  0.924609  0.973513
# 604   1.026414  0.883440  0.981613  ...  0.879182  1.007399  1.061668
# ...        ...       ...       ...  ...       ...       ...       ...
# 1795  1.094074  1.044293  0.764864  ...  1.076663  1.082087  1.165082
# 1796  0.960065  0.902691  0.971677  ...  1.279458  1.144574  1.035424
# 1797  1.168074  1.017146  1.151274  ...  1.081815  1.220156  0.860176
# 1798  1.010629  1.073026  1.043301  ...  0.974334  1.143813  1.065788
# 1799  1.021465  1.015228  1.077118  ...  0.819921  0.903953  0.952708
#
#         roi138    roi139    roi140    roi141    roi142    roi143    roi144
# 600   0.960283  0.855624  0.805520  1.051495  0.846596  0.959952  1.049141
# 601   1.120956  0.754257  1.024476  0.967338  1.127942  0.929552  1.007282
# 602   1.110346  0.696574  0.850771  1.020952  1.033757  1.051512  0.900327
# 603   0.879425  0.754767  0.847523  0.975474  1.063497  0.909870  0.848583
# 604   0.923289  0.620734  0.753364  1.095693  0.835282  1.173120  1.074217
# ...        ...       ...       ...       ...       ...       ...       ...
# 1795  0.944918  0.908084  1.055451  0.803923  0.779125  0.909120  1.018546
# 1796  0.967703  0.691743  0.687109  0.901050  0.898104  1.097513  1.054795
# 1797  1.058669  0.806177  1.031292  0.712499  0.819249  0.937118  1.084125
# 1798  0.989930  0.796534  0.682861  0.845753  0.679370  0.953646  0.943671
# 1799  0.979352  0.747240  0.684579  0.686912  0.877264  0.920842  1.112127
#
# [1200 rows x 145 columns]
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1195    3
# 1196    3
# 1197    3
# 1198    3
# 1199    3
# Name: cluster_label, Length: 1200, dtype: int64

# %%
print(np.shape(pca_result))
print(pca_result[1,1])
print(y)
for i in range(1200):
    plt.scatter(pca_result[i,0],pca_result[i,1])
# Out:
# (1200, 2)
# -0.27919480751661935
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1195    3
# 1196    3
# 1197    3
# 1198    3
# 1199    3
# Name: cluster_label, Length: 1200, dtype: int64

# %%
fig, ax = plt.subplots()
# PCA
pca = PCA(n_components=2,random_state=42)

pca_result = pca.fit_transform(patient_minimal)
print(pca.explained_variance_ratio_)
print(pca_result)


for l, c, m in zip([1,2,3], ["pink", "turquoise", "blue"], ('^', 's', "o")):
    ax.scatter(pca_result[y == l, 0],
                pca_result[y == l, 1],
                color=c,
                label='cluster %s' % l,
                alpha=0.9,
                marker=m
                )

plt.title("PCA analysis of Gene-SGAN imaging toy dataset with patients only")
labels = [1,2,3]
fig.legend(labels, loc='lower center',ncol=len(labels))
# Out:
# [0.10312374 0.06725271]
# [[-0.45934299 -0.09533456]
#  [-0.37639986 -0.27919481]
#  [-0.46595251  0.53384496]
#  ...
#  [ 0.00751909 -0.23714815]
#  [-0.15508066  0.54221539]
#  [ 0.02296227 -0.17101935]]
